# %%
import pandas as pd

# %%
df=pd.read_csv("arrestdatany.csv")
df
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0        238013474  12/18/2021  157.0                          RAPE 1  104.0
# 1        236943583  11/25/2021  263.0                     ARSON 2,3,4  114.0
# 2        234938876  10/14/2021  594.0                     OBSCENITY 1  116.0
# 3        234788259  10/11/2021  263.0                     ARSON 2,3,4  114.0
# 4        234188790  09/28/2021  578.0                             NaN    NaN
# ...            ...         ...    ...                             ...    ...
# 155502   222884924  01/10/2021  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 155503   223918625  02/03/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155504   224323770  02/13/2021  101.0                       ASSAULT 3  344.0
# 155505   222599533  01/04/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155506   224056881  02/06/2021  268.0              CRIMINAL MIS 2 & 3  121.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155507 entries, 0 to 155506
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                155507 non-null  int64
#  1   ARREST_DATE               155507 non-null  object
#  2   PD_CD                     155478 non-null  float64
#  3   PD_DESC                   155404 non-null  object
#  4   KY_CD                     155404 non-null  float64
#  5   OFNS_DESC                 155404 non-null  object
#  6   LAW_CODE                  155507 non-null  object
#  7   LAW_CAT_CD                154114 non-null  object
#  8   ARREST_BORO               155507 non-null  object
#  9   ARREST_PRECINCT           155507 non-null  int64
#  10  JURISDICTION_CODE         155507 non-null  int64
#  11  AGE_GROUP                 155507 non-null  object
#  12  PERP_SEX                  155507 non-null  object
# ...

# %%
df.rename(columns = {"ARREST_DATE": "arrest_date", "OFNS_DESC": "offense", "ARREST_BORO": "borough", "ARREST_PRECINCT":"precinct","AGE_GROUP":"age", "PERP_SEX":"perp_sex","PERP_RACE":"perp_race","Latitude":"latitude","Longitude": "longitude" }, inplace = True)

# %%
df
# Out:
#         ARREST_KEY arrest_date  PD_CD                         PD_DESC  KY_CD  \
# 0        238013474  12/18/2021  157.0                          RAPE 1  104.0
# 1        236943583  11/25/2021  263.0                     ARSON 2,3,4  114.0
# 2        234938876  10/14/2021  594.0                     OBSCENITY 1  116.0
# 3        234788259  10/11/2021  263.0                     ARSON 2,3,4  114.0
# 4        234188790  09/28/2021  578.0                             NaN    NaN
# ...            ...         ...    ...                             ...    ...
# 155502   222884924  01/10/2021  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 155503   223918625  02/03/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155504   224323770  02/13/2021  101.0                       ASSAULT 3  344.0
# 155505   222599533  01/04/2021  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 155506   224056881  02/06/2021  268.0              CRIMINAL MIS 2 & 3  121.0
#
# ...

# %%
df_tidy= df[["arrest_date",
            "PD_DESC",
            "offense",
            "borough",
            "precinct",
            "age",
            "perp_sex",
            "perp_race"
            ]]

df_tidy
# Out:
#        arrest_date                         PD_DESC  \
# 0       12/18/2021                          RAPE 1
# 1       11/25/2021                     ARSON 2,3,4
# 2       10/14/2021                     OBSCENITY 1
# 3       10/11/2021                     ARSON 2,3,4
# 4       09/28/2021                             NaN
# ...            ...                             ...
# 155502  01/10/2021  ROBBERY,OPEN AREA UNCLASSIFIED
# 155503  02/03/2021        WEAPONS POSSESSION 1 & 2
# 155504  02/13/2021                       ASSAULT 3
# 155505  01/04/2021        WEAPONS POSSESSION 1 & 2
# 155506  02/06/2021              CRIMINAL MIS 2 & 3
#
#                                offense borough  precinct    age perp_sex  \
# 0                                 RAPE       Q       105  18-24        M
# 1                                ARSON       K        69  25-44        M
# 2                           SEX CRIMES       K        61  25-44        M
# ...

# %%
df_tidy.shape
# Out:
# (155507, 8)

# %%
date_fil = df_tidy["arrest_date"] >= "['01/01/2021']"
date_fil
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 155502    False
# 155503    False
# 155504    False
# 155505    False
# 155506    False
# Name: arrest_date, Length: 155507, dtype: bool

# %%
date_fil.value_counts() ##need help creating a filter that contains only dates between Jan 2021 and Dec 2021
# Out:
# False    155507
# Name: arrest_date, dtype: int64

# %%
df_tidy['offense'].unique()
# Out:
# array(['RAPE', 'ARSON', 'SEX CRIMES', nan, 'ASSAULT 3 & RELATED OFFENSES',
#        'FELONY ASSAULT', 'DANGEROUS WEAPONS', 'MISCELLANEOUS PENAL LAW',
#        'PETIT LARCENY', 'GRAND LARCENY OF MOTOR VEHICLE',
#        'DANGEROUS DRUGS', 'NYS LAWS-UNCLASSIFIED FELONY', 'GRAND LARCENY',
#        'OTHER OFFENSES RELATED TO THEF',
#        'PROSTITUTION & RELATED OFFENSES',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'ROBBERY',
#        'FOR OTHER AUTHORITIES', 'CRIMINAL MISCHIEF & RELATED OF',
#        'OTHER TRAFFIC INFRACTION', 'FORGERY',
#        'INTOXICATED & IMPAIRED DRIVING', 'MURDER & NON-NEGL. MANSLAUGHTE',
#        'UNAUTHORIZED USE OF A VEHICLE', 'BURGLARY',
#        'OFFENSES INVOLVING FRAUD', 'VEHICLE AND TRAFFIC LAWS',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'THEFT OF SERVICES',
#        'CRIMINAL TRESPASS', 'POSSESSION OF STOLEN PROPERTY',
#        'OTHER STATE LAWS (NON PENAL LA', 'FRAUDULENT ACCOSTING',
# ...

# %%
## I can glob some of these together (e.g-'INTOXICATED & IMPAIRED DRIVING' and 'INTOXICATED/IMPAIRED DRIVING')

# %%
##Checked data and it ONLY contains 2021 data. Filter is no longer needed

# %%
df_tidy['offense'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0                                   RAPE
# 1                                  ARSON
# 2                             SEX CRIMES
# 3                                  ARSON
# 4                                    NaN
#                        ...
# 155502                           ROBBERY
# 155503                 DANGEROUS WEAPONS
# 155504      ASSAULT 3 & RELATED OFFENSES
# 155505                 DANGEROUS WEAPONS
# 155506    CRIMINAL MISCHIEF & RELATED OF
# Name: offense, Length: 155507, dtype: object>

# %%
##Why is arson the number one crime? are fire hazards easily accessible?

# %%
df_tidy['perp_sex'].value_counts()
# Out:
# M    128910
# F     26597
# Name: perp_sex, dtype: int64

# %%
##Men have been arrested for more crimes in the city than woman in 2021

# %%
df_tidy['perp_race'].value_counts()
# Out:
# BLACK                             77133
# WHITE HISPANIC                    38112
# WHITE                             17063
# BLACK HISPANIC                    13576
# ASIAN / PACIFIC ISLANDER           8593
# UNKNOWN                             587
# AMERICAN INDIAN/ALASKAN NATIVE      443
# Name: perp_race, dtype: int64

# %%
#Blacks have been arrested for more crimees in 2021 than any other race...

# %%
## what is white hispanic?

# %%
df_tidy['age'].value_counts()
# Out:
# 25-44    88850
# 45-64    30608
# 18-24    28951
# <18       4800
# 65+       2298
# Name: age, dtype: int64

# %%
##It would be interesting to compare this data with previous years to see if certain groups arreest rates have gone done

# %%
df_tidy['borough'].value_counts()
# Out:
# K    41550
# M    39677
# B    34018
# Q    33051
# S     7211
# Name: borough, dtype: int64

# %%
##brooklyn has had the most arrests in 2021 , staten island the least.

# %%
##COMPARE THIS DATA WITH POPULATIONS TO CREATE RATIOS SO ITS NOT JUST BOROUGH POPULATION SKEWING DATA

# %%
df_tidy['PD_DESC'].value_counts()
# Out:
# ASSAULT 3                         19766
# LARCENY,PETIT FROM OPEN AREAS,    13143
# ASSAULT 2,1,UNCLASSIFIED          11663
# ROBBERY,OPEN AREA UNCLASSIFIED     7809
# PUBLIC ADMINISTRATION,UNCLASSI     7135
#                                   ...
# PARKR&R,UNCLASSIFIED VIOLATION        1
# VIOLATION OF ORDER OF PROTECTI        1
# BRIBERY,FRAUD                         1
# LABOR TRAFFICKING                     1
# ONE WAY STREET                        1
# Name: PD_DESC, Length: 241, dtype: int64

# %%
#ok

# %%
df_tidy['precinct'].value_counts()
# Out:
# 14     4762
# 44     4387
# 75     4249
# 40     4070
# 47     3489
#        ...
# 100     827
# 123     798
# 76      772
# 111     700
# 22       50
# Name: precinct, Length: 77, dtype: int64

# %%
## the most arrests occurred in precinct 14, in manhattan?? look into this later...

# %%
df_tidy
# Out:
#        arrest_date                         PD_DESC  \
# 0       12/18/2021                          RAPE 1
# 1       11/25/2021                     ARSON 2,3,4
# 2       10/14/2021                     OBSCENITY 1
# 3       10/11/2021                     ARSON 2,3,4
# 4       09/28/2021                             NaN
# ...            ...                             ...
# 155502  01/10/2021  ROBBERY,OPEN AREA UNCLASSIFIED
# 155503  02/03/2021        WEAPONS POSSESSION 1 & 2
# 155504  02/13/2021                       ASSAULT 3
# 155505  01/04/2021        WEAPONS POSSESSION 1 & 2
# 155506  02/06/2021              CRIMINAL MIS 2 & 3
#
#                                offense borough  precinct    age perp_sex  \
# 0                                 RAPE       Q       105  18-24        M
# 1                                ARSON       K        69  25-44        M
# 2                           SEX CRIMES       K        61  25-44        M
# ...

# %%
df_tidy['PD_DESC'].value_counts()
# Out:
# ASSAULT 3                         19766
# LARCENY,PETIT FROM OPEN AREAS,    13143
# ASSAULT 2,1,UNCLASSIFIED          11663
# ROBBERY,OPEN AREA UNCLASSIFIED     7809
# PUBLIC ADMINISTRATION,UNCLASSI     7135
#                                   ...
# PARKR&R,UNCLASSIFIED VIOLATION        1
# VIOLATION OF ORDER OF PROTECTI        1
# BRIBERY,FRAUD                         1
# LABOR TRAFFICKING                     1
# ONE WAY STREET                        1
# Name: PD_DESC, Length: 241, dtype: int64

# %%
date_fil = df_tidy["arrest_date"] >= "['06/01/2021']"
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# /usr/local/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642         if res is None:
# --> 643             raise ParserError("Unknown string format: %s", timestr)
#     644
#
# ParserError: Unknown string format: ['06/01/2021']
#
# ...
